# %%
% matplotlib inline
from plot_setup import *
import model_definition as model
import seaborn as sns
#sns.set(style="ticks",palette="tab10")
sns.set_style('whitegrid')
sns.set_palette("tab10",10)
import matplotlib

#args_pairplot = {"size":5,"plot_kws":{"s":8,"marker":"o"},"diag_kws":{"bins":32,"histtype":"stepfilled","alpha":0.3}}
args_pairplot = {"plot_kws":{"s":8,"marker":"o"},"diag_kws":{"bins":32,"histtype":"stepfilled","alpha":0.3}}

def mypairplot(
    mcchain,
    scatter_kws={"s":1,"marker":"o","alpha":0.1},
    kde_kws={"shade":True,"shade_lowest":False,"cmap":"jet"},
    hist_kws={"bins":32,"histtype":"stepfilled","alpha":0.3},
    **kws):
    
    print("Note: The following warnings occur, but no problem.\nUserWarning: The following kwargs were not used by contour: 'label', 'color' ")
    g = sns.PairGrid(mcchain,**kws)
    g = g.map_upper(plt.scatter,**scatter_kws)
    g = g.map_lower(sns.kdeplot,**kde_kws)
    g = g.map_diag(plt.hist, **hist_kws)
    return g

# %%
mem = pd.read_csv("mock_mem_v005.csv")[::]
mypairplot(mem,hist_kws={"bins":32,"histtype":"stepfilled","alpha":0.3})
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
mem.describe()
# Out:
#                   v             R
# count  25000.000000  25000.000000
# mean      49.993773     86.676182
# std       17.931370     47.205760
# min        0.006647      0.434951
# 25%       38.220963     48.926094
# 50%       49.905130     79.729585
# 75%       61.929030    119.872939
# max       99.912543    199.998402

# %%
mem = pd.read_csv("mock_fg_v005.csv")[::]
mypairplot(mem,hist_kws={"bins":32,"histtype":"stepfilled","alpha":0.3})
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
pd.read_csv("mclog_memonly_v004.csv")
# Out:
#           a         b     v_mem  iter_num
# 0  0.200000  0.200000  0.200000      5000
# 1  0.152302  0.232262  0.112136      5000
# 2  0.153648  0.228585  0.105311     25000

# %%
fname = "memonly_v004"
# memonly_v003: MCMC, 5000 stars 
# memonly_v004: MCMC, 25000 stars 
display(pd.read_csv("mclog_"+fname+".csv"))
mcchain = pd.read_csv("params_chain_"+fname+".csv")[-25000::5]
mypairplot(mcchain)
# Out:
#           a         b     v_mem  iter_num
# 0  0.200000  0.200000  0.200000      5000
# 1  0.152302  0.232262  0.112136      5000
# 2  0.153648  0.228585  0.105311     25000
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
mcchain.cov()
# Out:
#            v_mem         a         b    logpdf
# v_mem   0.012608 -0.000049  0.000168 -0.000817
# a      -0.000049  0.023524 -0.030428 -0.012460
# b       0.000168 -0.030428  0.055293  0.014067
# logpdf -0.000817 -0.012460  0.014067  1.431938

# %%
np.linalg.eig([[0.235,-0.304],[-0.304,0.553]])
# Out:
# (array([0.05093004, 0.73706996]), array([[-0.85541286,  0.51794676],
#         [-0.51794676, -0.85541286]]))

# %%
mcchain = pd.read_csv("params_chain_memonly_v004.csv")[-30000::5]
mypairplot(mcchain)
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
pd.read_csv("mclog_memonly_v004.csv")
# Out:
#           a         b     v_mem  iter_num
# 0  0.200000  0.200000  0.200000      5000
# 1  0.152302  0.232262  0.112136      5000
# 2  0.153648  0.228585  0.105311     25000

# %% [markdown]
# # mocks without MCMC

# %%
mem = pd.read_csv("mock_mem_noMCMC_v001_1milion.csv")[::100]
mypairplot(mem[(mem.R<200).values * (mem.v<100).values * (mem.v>0).values],vars={"v","R"},hist_kws={"bins":32,"histtype":"stepfilled","alpha":0.3})
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
mem = pd.read_csv("mock_mem_noMCMC_v001_0b.csv")[::5]
mypairplot(mem,vars={"v","R"},hist_kws={"bins":32,"histtype":"stepfilled","alpha":0.3})
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
fname = "noMCMC_v001_0b"
# memonly_v003: MCMC, 5000 stars 
# memonly_v004: MCMC, 25000 stars 
display(pd.read_csv("mclog_"+fname+".csv"))
mcchain = pd.read_csv("params_chain_"+fname+".csv")[-20000::5]
mypairplot(mcchain)
# Out:
#           a         b     v_mem  iter_num
# 0  0.200000  0.200000  0.200000      5000
# 1  0.490873  1.513046  0.102252      5000
# 2  0.104084  0.336711  0.090971      5000
# 3  0.114581  0.379035  0.097291     20000
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...
