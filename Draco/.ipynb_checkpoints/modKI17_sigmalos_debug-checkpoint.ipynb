# %% [markdown]
# # Code

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from plot_setup import * 
import MCgenerator, dSph_model, coord
from numpy import power,sqrt
from scipy.stats import norm

# %%
# %autoreload 2

# %%
dSph_property = pd.read_csv("dSph_property.csv",index_col=0)
draco_prop = dSph_property.loc["Draco"]
RA0 = draco_prop.RAdeg
DE0 = draco_prop.DEdeg
DIST = draco_prop.DIST
dSph_property
# Out:
#        RAh  RAm  RAs  pmDEd  DEm  DEs     DIST    HLR   RAdeg      DEdeg
# Draco   17   20   12     57   54   55  76000.0  221.0  260.05  57.915278

# %%
SPECIFY_NAME = "spectroscopy_cont_refR-re-w-center_plummer_Rcont-3000pc"
FNAME_BASE = "MCMCresult/MCMC{}_{}_{}.csv"
VERSION="v001"
# v001: for mycut
# v002: for spectroscopy cut

# %% [markdown]
# ## definition of likelihood

# %%
class KI17_loglikelihood_mod_cont:
    def __init__(self,vs,beta=1):
        self.vs = vs
        self.beta = beta
        #print(Rs.describe())
        print("beta: {}".format(self.beta)) if beta != 1 else None
        
    def __call__(self,**args):
        return np.sum(self.loglikelis(**args))
    
    def is_parameters_in_domain(self,
            vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1):
        is_positive_ = np.all(is_positive(dvfg0,dvfg1,dvfg2))
        is_vfg_ordered_ = vfg0 < vfg1 < vfg2
        is_ffg_normalized_ = 0<=sfg0<=1 and 0<=sfg1<=1 and (sfg0+sfg1)<=1
        is_not_fast = np.all(np.abs(np.array([vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2]))<3e8)
        return (is_positive_ and is_vfg_ordered_ and is_ffg_normalized_ and is_not_fast)
    
    def loglikelis(
        self,
            vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1
    ): # R_trunc_pc is fixed 2000 pc
        if not self.is_parameters_in_domain(vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1):
            return -np.inf
        else:
            vs=self.vs
            sfg2 = 1-sfg0-sfg1
            
            ffg0 = sfg0 * norm.pdf(vs,loc=vfg0,scale=dvfg0)
            ffg1 = sfg1 * norm.pdf(vs,loc=vfg1,scale=dvfg1)
            ffg2 = sfg2 * norm.pdf(vs,loc=vfg2,scale=dvfg2)
            ffg = ffg0+ffg1+ffg2
            
            ret = np.log(ffg)

            return self.beta * ret
        
    def fit_plot(self,vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1,bins=64,**kwargs):
        fig,ax = plt.subplots(1,1)
        vs=self.vs
        sfg2 = 1-sfg0-sfg1 
        ffg0 = sfg0 * norm.pdf(vs,loc=vfg0,scale=dvfg0)
        ffg1 = sfg1 * norm.pdf(vs,loc=vfg1,scale=dvfg1)
        ffg2 = sfg2 * norm.pdf(vs,loc=vfg2,scale=dvfg2)
        ffg = ffg0+ffg1+ffg2
        df = pd.DataFrame()
        df[r"$v$"] = vs
        df["$f_{FG,0}$"] = ffg0
        df["$f_{FG,1}$"] = ffg1
        df["$f_{FG,2}$"] = ffg2
        df["$f_{FG,tot}$"] = ffg
        
        df = df.sort_values(r"$v$")
        
        ax.hist(vs,density=True,bins=bins)
        df.plot(x=r"$v$",ax=ax,**kwargs)

# %%
#update likelihood
def is_positive(*args):
    return np.array(args)>0

class KI17_loglikelihood_mod:
    def __init__(self,vs,dRAs,dDEs,beta=1):
        self.vs = vs
        self.dRAs = dRAs
        self.dDEs = dDEs
        self.RoI_R = np.max(self.Rs(0,0)) # use Rs.max as the RoI
        self.beta = beta
        #print(Rs.describe())
        print("beta: {}".format(self.beta)) if beta != 1 else None
        mem = dSph_model.plummer_model(re_pc=200)
        dm = dSph_model.NFW_model(a=2.78,b=7.78,g=0.675,rhos_Msunpc3=np.power(10,-2.05),rs_pc=np.power(10,3.96),R_trunc_pc=2000)
        self.dsph = dSph_model.dSph_model(anib=-0.5,submodels_dict={"stellar_model":mem,"DM_model":dm},show_init=True)
        
        self.fg = dSph_model.uniform2d_model(Rmax_pc=self.RoI_R,show_init=True)


    def Rs(self,dra0,dde0):
        return coord.projected_distance(
            dist=DIST,
            ra_center = RA0+dra0,
            de_center = DE0+dde0,
            ra = RA0+self.dRAs,
            de = DE0+self.dDEs,
            dtype="deg")

    def logprior(self,re,odds,dra0,dde0,
            log10_rs_pc,log10_rhos_Msunpc3,a,b,g,
            mlog10_1manib,
            vmem,vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1):
        
        G_re = norm.pdf(re,loc=191,scale=5.7)
        #G_odds = norm.pdf(odds,loc=8.794,scale=0.5107)
        G_dra0 = norm.pdf(dra0,loc=4.212e-3,scale=7.052e-3)
        G_dde0 = norm.pdf(dde0,loc=-1.991e-3,scale=3.302e-3)
        
        return np.sum(np.log([G_re,G_dra0,G_dde0]))
    
    def __call__(self,**args):
        return np.sum(self.loglikelis(**args)) + self.logprior(**args)
    
    def is_parameters_in_domain(self,re,odds,dra0,dde0,
            log10_rs_pc,log10_rhos_Msunpc3,a,b,g,
            mlog10_1manib,
            vmem,vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1):
        is_positive_ = np.all(is_positive(re,odds,dvfg0,dvfg1,dvfg2))
        is_vfg_ordered_ = vfg0 <= vfg1 <= vfg2
        is_ffg_normalized_ = 0<=sfg0<=1 and 0<=sfg1<=1 and (sfg0+sfg1)<=1
        is_in_domain_ = -1<mlog10_1manib<1 and -4<log10_rhos_Msunpc3<4 and 0<log10_rs_pc<5 and 0.5<a<3 and 3<b<10 and 0<g<1.2
        is_not_fast = np.all(np.abs(np.array([vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2]))<3e8)
        return (is_positive_ and is_vfg_ordered_ and is_ffg_normalized_ and is_in_domain_ and is_not_fast)
    
    def loglikelis(
        self,re,odds,dra0,dde0,
            log10_rs_pc,log10_rhos_Msunpc3,a,b,g,
            mlog10_1manib,
            vmem,vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1
    ): # R_trunc_pc is fixed 2000 pc
        if not self.is_parameters_in_domain(re,odds,dra0,dde0,
                log10_rs_pc,log10_rhos_Msunpc3,a,b,g,
                mlog10_1manib,
                vmem,vfg0,vfg1,vfg2,dvfg0,dvfg1,dvfg2, sfg0, sfg1):
            return -np.inf
        else:
            vs=self.vs
            mem,dm,fg = self.dsph.submodels["stellar_model"],self.dsph.submodels["DM_model"],self.fg
            mem.update({"re_pc":re})
            dm.update({"rs_pc":power(10,log10_rs_pc),"rhos_Msunpc3":power(10,log10_rhos_Msunpc3),"a":a,"b":b,"g":g})
            self.dsph.update({"anib":1-power(10,-mlog10_1manib)})
            ref_R = mem.half_light_radius() # 1.67834699001666*re
            
            #display("calc_Rs start")
            Rs = self.Rs(dra0,dde0)
            #display("Rs",Rs)
        
            s = 1/(1+ 1/(odds * mem.density_2d_normalized_re(Rs)))
            #sigmalos2 = self.dsph.sigmalos2_interp1d(Rs,step_inner=8,step_outer=16)
            sigmalos = self.dsph.sigmalos_interp1d(Rs,step_around_Rtrunc=4,step_center=2,step_outer=16)
            #sigmalos = self.dsph.sigmalos_dequad_interp1d_downsampled(Rs)
            sfg2 = 1-sfg0-sfg1
            
            fmem = norm.pdf(vs,loc=vmem,scale=sigmalos)
            
            ffg0 = sfg0 * norm.pdf(vs,loc=vfg0,scale=dvfg0)
            ffg1 = sfg1 * norm.pdf(vs,loc=vfg1,scale=dvfg1)
            ffg2 = sfg2 * norm.pdf(vs,loc=vfg2,scale=dvfg2)
            ffg = ffg0+ffg1+ffg2
            
            ret = np.log(s*fmem+(1-s)*ffg)

            return self.beta * ret

# %%
df0 = pd.read_csv("dra_sspp2_RADEdeg.csv")
#display(df0)
df_deg = pd.DataFrame(df0[["RAdeg","DEdeg"]])
df_rad = np.deg2rad(pd.DataFrame(df_deg))

df_deg["x"] = df_deg["RAdeg"] - RA0
df_deg["y"] = df_deg["DEdeg"] - DE0

#ra = coord.hms_to_deg(df.RAh,df.RAm,df.RAs) + ra0
#de = coord.dms_to_deg(df.pmDEd,df.DEm,df.DEs) + de0
ra = df_deg.RAdeg
de = df_deg.DEdeg
vs = df0.Vlos

arg_proj_dist = {
    "ra":ra,"de":de,
    "ra_center":RA0,"de_center":DE0
}
angles = coord.projected_angle(**arg_proj_dist,dtype="deg")
Rs = coord.projected_distance(dist=DIST,**arg_proj_dist,dtype="deg")
distort = np.cos(np.deg2rad(draco_prop.DEdeg))
deg_max = 4
df_deg[(np.abs(df_deg.x)<deg_max/distort).values * (np.abs(df_deg.y)<deg_max).values].plot.scatter("x","y",s=1,figsize=(6,6))
plt.xlabel(r"$x$[deg]")
plt.ylabel(r"$y$[deg]")
# Out:
# Text(0,0.5,'$y$[deg]')

# %% [markdown]
# ## density of ofserbed stars

# %%
pd.DataFrame({r"$\theta$[deg]":angles}).hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09b1b1d8d0>]],
#       dtype=object)

# %%
pd.DataFrame({r"$R$[pc]":Rs}).hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09a9b64f60>]],
#       dtype=object)

# %%
df0[["RAdeg","DEdeg","Vlos"]].plot_scatter3D("RAdeg","DEdeg","Vlos",s=1)

# %%
df_vlos = pd.DataFrame({r"$v_{los}$[km/s]":df0.Vlos.values})
df_vlos.hist(bins=64)
len(df0)
plt.yscale("log")

# %%
df_plot = df0[Rs>900]
bins = np.linspace(-500,200,32)
df0[Rs>1190].hist("Vlos",bins=bins)
df0[Rs>830].hist("Vlos",bins=bins)
df0[Rs>670].hist("Vlos",bins=bins)

display([len(df0[Rs>1190]),len(df0[Rs>830]),len(df0[Rs>670])])
# Out:
# [429, 730, 843]

# %%
df0[angles<2.5].hist("Vlos",bins=64)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f09a93a7f60>]],
#       dtype=object)

# %% [markdown]
# ## likelihood compile

# %%
isin_sig = Rs<3000 #670(92.5%), 830(95%), 1190(97.5%) 1900(99%), 3000
loglikeli_cont =  KI17_loglikelihood_mod_cont(vs=vs[np.logical_not(isin_sig)])
loglikeli = KI17_loglikelihood_mod(vs=vs[isin_sig].values,dRAs=df_deg.x[isin_sig].values,dDEs=df_deg.y[isin_sig].values)
#sigmalos2 = loglikeli.dsph.sigmalos2_using_mykernel(loglikeli.Rs(0,0))
#loglikeli = KI17_loglikelihood(Rs[angles<1.0])
# Out:
# initialized:
# re_pc            200.000000
# a                  2.780000
# b                  7.780000
# g                  0.675000
# rhos_Msunpc3       0.008913
# rs_pc           9120.108394
# R_trunc_pc      2000.000000
# dtype: float64
# initialized:
# Rmax_pc    2531.745788
# dtype: float64

# %%
loglikeli(**{
"re"                  :  194.995481,
"odds"                :    8.403337,
"dra0"                :    0.013713,
"dde0"                :   -0.003668,
"log10_rs_pc"         :    4.210851,
"log10_rhos_Msunpc3"  :   -1.933728,
"a"                   :    0.569358,
"b"                   :    8.067588,
"g"                   :    0.742696,
"mlog10_1manib"       :   -0.614631,
"vmem"                : -292.490077,
"vfg0"                : -180.391567,
"vfg1"                :  -51.857606,
"dvfg0"               :   95.371709,
"dvfg1"               :   40.519504,
"sfg0"                :    0.504171,
"vfg2":0,"dvfg2":1,"sfg1":0
})
loglikeli.dsph.update({
"re_pc"                  :  194.995481,
"log10_rs_pc"         :    4.210851,
"log10_rhos_Msunpc3"  :   -1.933728,
"a"                   :    0.569358,
"b"                   :    8.067588,
"g"                   :    0.742696,
"mlog10_1manib"       :   -0.614631})

# %%
# %%time
R_pc = np.sort(loglikeli.Rs(0,0))[::100]
ys0 = loglikeli.dsph.sigmalos2(R_pc)
plt.plot(R_pc,ys0)
# Out:
# CPU times: user 1.17 s, sys: 0 ns, total: 1.17 s
# Wall time: 1.16 s

# %%
display(loglikeli.dsph)
us = np.linspace(1,5,1000)
for R_pc in np.linspace(50,500,5):#,100,200,1000,2000,3000,4000):
    ys = loglikeli.dsph.integrand_sigmalos2_using_mykernel(arg_R_pc=R_pc,u=us)
    R_trunc_pc= loglikeli.dsph.submodels["DM_model"].params.R_trunc_pc
    re_pc= loglikeli.dsph.submodels["stellar_model"].params.re_pc
    plt.plot(us,ys,label="R_pc="+str(R_pc)+"   u_trunc:"+str(R_trunc_pc/R_pc)+"   u_e:"+str(re_pc/R_pc))
    #display(ys)
plt.legend()
plt.xscale("linear")
plt.yscale("log")
display(R_trunc_pc)
# Out:
# : Plummer model and NFW model:
# re_pc             194.995481
# a                   0.569358
# b                   8.067588
# g                   0.742696
# rhos_Msunpc3        0.011649
# rs_pc           16249.911497
# R_trunc_pc       2000.000000
# dtype: float64
# 2000.0

# %%
# %%time
R_pc = np.sort(loglikeli.Rs(0,0))[::100]
ys1 = loglikeli.dsph.sigmalos2_using_mykernel(R_pc)
plt.plot(R_pc,ys1)
# Out:
# CPU times: user 1.17 s, sys: 0 ns, total: 1.17 s
# Wall time: 1.16 s

# %%
# %%time
R_pc = np.sort(loglikeli.Rs(0,0))[::4]
ys0 = sqrt(loglikeli.dsph.sigmalos2_multi_using_mykernel(R_pc))
plt.plot(R_pc,(ys0))
plt.xscale("linear")
# Out:
# CPU times: user 80 ms, sys: 0 ns, total: 80 ms
# Wall time: 8.34 s

# %%
# %%time
R_pc = np.sort(loglikeli.Rs(0,0))[::4]
ys1 = loglikeli.dsph.sigmalos_interp1d(R_pc,step_around_Rtrunc=4,step_center=2,step_outer=16)
plt.plot(R_pc,ys1)
plt.xscale("linear")
# Out:
# CPU times: user 92 ms, sys: 36 ms, total: 128 ms
# Wall time: 707 ms

# %%
plt.plot(R_pc,(np.array(ys1)-np.array(ys0))/np.array(ys0))
min(R_pc)
plt.xscale("linear")

# %%
R_pc = np.sort(loglikeli.Rs(0,0))[::4]
#%time ys0 = sqrt(loglikeli.dsph.sigmalos2_multi_using_mykernel(R_pc))
for R in R_pc:
    ys1 = loglikeli.dsph.sigmalos_dequad(np.array([R,]),show_fig=True)
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
R_pc = np.sort(loglikeli.Rs(0,0))[::100]
#%time ys0 = sqrt(loglikeli.dsph.sigmalos2_multi_using_mykernel(R_pc))
for R in R_pc:
    ys1 = loglikeli.dsph.sigmalos_dequad(np.array([R,]),show_fig=True)
# Out:
# array([[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          1.59471052e-026,  1.90587963e-026,  2.27568707e-026,
#          2.71478262e-026,  3.23567572e-026,  3.85304688e-026,
#          6.48290890e-026,  7.70608528e-026,  9.15193441e-026,
#          1.33000947e-025,  1.57677588e-025,  2.15662930e-025,
#          2.55231628e-025,  3.37421843e-025,  4.36690852e-025,
#          5.56783317e-025,  7.44607618e-025,  9.24926868e-025,
#          1.19298004e-024,  1.51592440e-024,  1.96357092e-024,
#          2.50141168e-024,  3.21562268e-024,  4.07259101e-024,
#          5.17995384e-024,  6.59211766e-024,  8.28268198e-024,
#          1.05056967e-023,  1.33761537e-023,  1.68015775e-023,
#          2.12628186e-023,  2.68455511e-023,  3.37793613e-023,
#          4.24922015e-023,  5.33462689e-023,  6.69507290e-023,
#          8.38589164e-023,  1.04933772e-022,  1.31223097e-022,
#          1.63993824e-022,  2.04518226e-022,  2.54847736e-022,
#          3.17468788e-022,  3.94441201e-022,  4.90176940e-022,
#          6.07903395e-022,  7.53692503e-022,  9.32837844e-022,
#          1.15376643e-021,  1.42519968e-021,  1.75848011e-021,
#          2.16766065e-021,  2.66891256e-021,  3.28263320e-021,
#          4.03306139e-021,  4.95032641e-021,  6.07017817e-021,
#          7.43492445e-021,  9.09706527e-021,  1.11195847e-020,
#          1.35778157e-020,  1.65626332e-020,  2.01833010e-020,
#          2.45707803e-020,  2.98815682e-020,  3.63034616e-020,
#          4.40625204e-020,  5.34269775e-020,  6.47190093e-020,
#          7.83192901e-020,  9.46854119e-020,  1.14359905e-019,
#          1.37990317e-019,  1.66342960e-019,  2.00331360e-019,
#          2.41034108e-019,  2.89734127e-019,  3.47944878e-019,
#          4.17461481e-019,  5.00398102e-019,  5.99257575e-019,
#          7.16987913e-019,  8.57056230e-019,  1.02355644e-018,
    dargs_logpdf={
        'vfg0':30, 'vfg1':8, 'vfg2':0.001, 'dvfg0':15, 'dvfg1':6,'dvfg2':0.001,
        'sfg0':0.05,'sfg1':0.05
    },
    logpdf_func=loglikeli_cont
)
# Out:
# initialization of MCgenerator start.
# function loaded.
# logpdf_initialization completed.
# Data chains are initialized.
# update dargs_logpdf:
# before:
# {}
# after:
# vfg0     30.000
# vfg1      8.000
# vfg2      0.001
# dvfg0    15.000
# dvfg1     6.000
# dvfg2     0.001
# sfg0      0.050
# sfg1      0.050
# dtype: float64
# MCparameters are initialized.

# %%
loglikeli_cont(**{
        'vfg0':-4e8, 'vfg1':-200, 'vfg2':-0, 'dvfg0':50, 'dvfg1':50,'dvfg2':50,
        'sfg0':0.01,'sfg1':0.2
    })
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-246-2b7a95d0b463> in <module>()
#       2         'vfg0':-4e8, 'vfg1':-200, 'vfg2':-0, 'dvfg0':50, 'dvfg1':50,'dvfg2':50,
#       3         'sfg0':0.01,'sfg1':0.2
# ----> 4     },kwargs={"figsize":(12,12)})
#
# <ipython-input-243-5d25d3b19ed5> in __call__(self, **args)
#       7
#       8     def __call__(self,**args):
# ----> 9         return np.sum(self.loglikelis(**args))
#      10
#      11     def is_parameters_in_domain(self,
#
# TypeError: loglikelis() got an unexpected keyword argument 'kwargs'

# %%
Nstep_init = 10000
gen_cont.generate(Nstep_init)
# Out:
# MCgeneration start.
# options: {}
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0     30.000
# vfg1      8.000
# vfg2      0.001
# dvfg0    15.000
# dvfg1     6.000
# dvfg2     0.001
# sfg0      0.050
# sfg1      0.050
# dtype: float64

# %%
#gen_cont.generate(100000)
gen_cont.generate_tuned([100000]*10)
# Out:
# MCgeneration start.
# options: {}
# 25.572% completed... acceptance rate: 1.13%
# 51.058% completed... acceptance rate: 1.15%
# 76.339% completed... acceptance rate: 1.20%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0     30.000
# vfg1      8.000
# vfg2      0.001
# dvfg0    15.000
# dvfg1     6.000
# dvfg2     0.001
# sfg0      0.050
# sfg1      0.050
# vfg0     30.000
# vfg1      8.000
# vfg2      0.001
# dvfg0    15.000
# dvfg1     6.000
# dvfg2     0.001
# sfg0      0.050
# sfg1      0.050
# dtype: float64
# 0th itetation
# update dargs_logpdf:
# before:
# vfg0     30.000
# vfg1      8.000
# vfg2      0.001
# dvfg0    15.000
# dvfg1     6.000
# dvfg2     0.001
# sfg0      0.050
# sfg1      0.050
# dtype: float64
# after:
# vfg0     11.082646
# vfg1      3.143810
# vfg2      0.009151
# dvfg0     6.045722
# dvfg1     2.583704
# dvfg2     0.007146
# sfg0      0.040028
# sfg1      0.040266
# dtype: float64
# MCgeneration start.
# options: {}
# 24.292% completed... acceptance rate: 7.52%
# 49.013% completed... acceptance rate: 7.33%
# 73.629% completed... acceptance rate: 7.34%
# 98.039% completed... acceptance rate: 7.46%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     11.082646
# vfg1      3.143810
# vfg2      0.009151
# dvfg0     6.045722
# dvfg1     2.583704
# dvfg2     0.007146
# sfg0      0.040028
# sfg1      0.040266
# dtype: float64
# 1th itetation
# update dargs_logpdf:
# before:
# vfg0     11.082646
# vfg1      3.143810
# vfg2      0.009151
# dvfg0     6.045722
# dvfg1     2.583704
# dvfg2     0.007146
# sfg0      0.040028
# sfg1      0.040266
# dtype: float64
# after:
# vfg0     10.655807
# vfg1      3.171886
# vfg2      0.148470
# dvfg0     5.794971
# dvfg1     2.374150
# dvfg2     0.080654
# sfg0      0.037649
# sfg1      0.037894
# dtype: float64
# MCgeneration start.
# options: {}
# 21.286% completed... acceptance rate: 14.52%
# 40.359% completed... acceptance rate: 16.98%
# 59.621% completed... acceptance rate: 17.96%
# 77.022% completed... acceptance rate: 18.47%
# 96.514% completed... acceptance rate: 18.68%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     11.082646
# vfg1      3.143810
# vfg2      0.009151
# dvfg0     6.045722
# dvfg1     2.583704
# dvfg2     0.007146
# sfg0      0.040028
# sfg1      0.040266
# vfg0     10.655807
# vfg1      3.171886
# vfg2      0.148470
# dvfg0     5.794971
# dvfg1     2.374150
# dvfg2     0.080654
# sfg0      0.037649
# sfg1      0.037894
# dtype: float64
# 2th itetation
# update dargs_logpdf:
# before:
# vfg0     10.655807
# vfg1      3.171886
# vfg2      0.148470
# dvfg0     5.794971
# dvfg1     2.374150
# dvfg2     0.080654
# sfg0      0.037649
# sfg1      0.037894
# dtype: float64
# after:
# vfg0     11.370338
# vfg1      4.100494
# vfg2      1.886307
# dvfg0     6.017851
# dvfg1     3.217763
# dvfg2     2.440693
# sfg0      0.040906
# sfg1      0.052383
# dtype: float64
# MCgeneration start.
# options: {}
# 19.145% completed... acceptance rate: 14.33%
# 38.444% completed... acceptance rate: 13.64%
# 60.228% completed... acceptance rate: 12.98%
# 87.306% completed... acceptance rate: 10.79%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     30.000000
# vfg1      8.000000
# vfg2      0.001000
# dvfg0    15.000000
# dvfg1     6.000000
# dvfg2     0.001000
# sfg0      0.050000
# sfg1      0.050000
# vfg0     11.082646
# vfg1      3.143810
# vfg2      0.009151
# dvfg0     6.045722
# dvfg1     2.583704
# dvfg2     0.007146
# sfg0      0.040028
# sfg1      0.040266
# vfg0     10.655807
# vfg1      3.171886
# vfg2      0.148470
# dvfg0     5.794971
# dvfg1     2.374150
# dvfg2     0.080654
# sfg0      0.037649
# sfg1      0.037894
# vfg0     11.370338
# vfg1      4.100494
# vfg2      1.886307
# dvfg0     6.017851
# dvfg1     3.217763
# dvfg2     2.440693
# sfg0      0.040906
# sfg1      0.052383
# dtype: float64
# 3th itetation
# update dargs_logpdf:
# before:
# vfg0     11.370338
# vfg1      4.100494
# vfg2      1.886307
# dvfg0     6.017851
# dvfg1     3.217763
# dvfg2     2.440693
# sfg0      0.040906
# sfg1      0.052383
# dtype: float64
# after:
# vfg0      87.197275
# vfg1      52.412060
# vfg2      17.040431
# dvfg0    139.303053
# dvfg1     22.292290
# dvfg2     11.074244
# sfg0       0.148041
# sfg1       0.096570
# dtype: float64
# MCgeneration start.
# options: {}
# 30.492% completed... acceptance rate: 0.04%
# 60.333% completed... acceptance rate: 0.03%
# 88.466% completed... acceptance rate: 0.02%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0      30.000000
# vfg1       8.000000
# vfg2       0.001000
# dvfg0     15.000000
# dvfg1      6.000000
# dvfg2      0.001000
# sfg0       0.050000
# sfg1       0.050000
# vfg0      30.000000
# vfg1       8.000000
# vfg2       0.001000
# dvfg0     15.000000
# dvfg1      6.000000
# dvfg2      0.001000
# sfg0       0.050000
# sfg1       0.050000
# vfg0      11.082646
# vfg1       3.143810
# vfg2       0.009151
# dvfg0      6.045722
# dvfg1      2.583704
# dvfg2      0.007146
# sfg0       0.040028
# sfg1       0.040266
# vfg0      10.655807
# vfg1       3.171886
# vfg2       0.148470
# dvfg0      5.794971
# dvfg1      2.374150
# dvfg2      0.080654
# sfg0       0.037649
# sfg1       0.037894
# vfg0      11.370338
# vfg1       4.100494
# vfg2       1.886307
# dvfg0      6.017851
# dvfg1      3.217763
# dvfg2      2.440693
# sfg0       0.040906
# sfg1       0.052383
# vfg0      87.197275
# vfg1      52.412060
# vfg2      17.040431
# dvfg0    139.303053
# dvfg1     22.292290
# dvfg2     11.074244
# sfg0       0.148041
# sfg1       0.096570
# dtype: float64
# 4th itetation
# update dargs_logpdf:
# before:
# vfg0      87.197275
# vfg1      52.412060
# vfg2      17.040431
# dvfg0    139.303053
# dvfg1     22.292290
# dvfg2     11.074244
# sfg0       0.148041
# sfg1       0.096570
# dtype: float64
# after:
# vfg0     122.406448
# vfg1       7.923877
# vfg2       2.653840
# dvfg0    134.605667
# dvfg1      3.435093
# dvfg2      2.162763
# sfg0       0.004655
# sfg1       0.021699
# dtype: float64
# MCgeneration start.
# options: {}
# 20.966% completed... acceptance rate: 26.63%
# 43.133% completed... acceptance rate: 26.37%
# 65.151% completed... acceptance rate: 26.44%
# 87.298% completed... acceptance rate: 26.38%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0      30.000000
# vfg1       8.000000
# vfg2       0.001000
# dvfg0     15.000000
# dvfg1      6.000000
# dvfg2      0.001000
# sfg0       0.050000
# sfg1       0.050000
# vfg0      30.000000
# vfg1       8.000000
# vfg2       0.001000
# dvfg0     15.000000
# dvfg1      6.000000
# dvfg2      0.001000
# sfg0       0.050000
# sfg1       0.050000
# vfg0      11.082646
# vfg1       3.143810
# vfg2       0.009151
# dvfg0      6.045722
# dvfg1      2.583704
# dvfg2      0.007146
# sfg0       0.040028
# sfg1       0.040266
# vfg0      10.655807
# vfg1       3.171886
# vfg2       0.148470
# dvfg0      5.794971
# dvfg1      2.374150
# dvfg2      0.080654
# sfg0       0.037649
# sfg1       0.037894
# vfg0      11.370338
# vfg1       4.100494
# vfg2       1.886307
# dvfg0      6.017851
# dvfg1      3.217763
# dvfg2      2.440693
# sfg0       0.040906
# sfg1       0.052383
# vfg0      87.197275
# vfg1      52.412060
# vfg2      17.040431
# dvfg0    139.303053
# dvfg1     22.292290
# dvfg2     11.074244
# sfg0       0.148041
# sfg1       0.096570
# vfg0     122.406448
# vfg1       7.923877
# vfg2       2.653840
# dvfg0    134.605667
# dvfg1      3.435093
# dvfg2      2.162763
# sfg0       0.004655
# sfg1       0.021699
# dtype: float64
# 5th itetation
# update dargs_logpdf:
# before:
# vfg0     122.406448
# vfg1       7.923877
# vfg2       2.653840
# dvfg0    134.605667
# dvfg1      3.435093
# dvfg2      2.162763
# sfg0       0.004655
# sfg1       0.021699
# dtype: float64
# after:
# vfg0     1678.592475
# vfg1       13.576505
# vfg2        3.049993
# dvfg0    3158.581134
# dvfg1       6.359974
# dvfg2       2.402251
# sfg0        0.002945
# sfg1        0.041734
# dtype: float64
# MCgeneration start.
# options: {}
# 20.261% completed... acceptance rate: 18.21%
# 41.909% completed... acceptance rate: 17.65%
# 63.499% completed... acceptance rate: 17.65%
# 84.604% completed... acceptance rate: 17.93%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg0       30.000000
# vfg1        8.000000
# vfg2        0.001000
# dvfg0      15.000000
# dvfg1       6.000000
# dvfg2       0.001000
# sfg0        0.050000
# sfg1        0.050000
# vfg0       30.000000
# vfg1        8.000000
# vfg2        0.001000
# dvfg0      15.000000
# dvfg1       6.000000
# dvfg2       0.001000
# sfg0        0.050000
# sfg1        0.050000
# vfg0       11.082646
# vfg1        3.143810
# vfg2        0.009151
# dvfg0       6.045722
# dvfg1       2.583704
# dvfg2       0.007146
# sfg0        0.040028
# sfg1        0.040266
# vfg0       10.655807
# vfg1        3.171886
# vfg2        0.148470
# dvfg0       5.794971
# dvfg1       2.374150
# dvfg2       0.080654
#             ...
# vfg2        1.886307
# dvfg0       6.017851
# dvfg1       3.217763
# dvfg2       2.440693
# sfg0        0.040906
# sfg1        0.052383
# vfg0       87.197275
# vfg1       52.412060
# vfg2       17.040431
# dvfg0     139.303053
# dvfg1      22.292290
# dvfg2      11.074244
# sfg0        0.148041
# sfg1        0.096570
# vfg0      122.406448
# vfg1        7.923877
# vfg2        2.653840
# dvfg0     134.605667
# dvfg1       3.435093
# dvfg2       2.162763
# sfg0        0.004655
# sfg1        0.021699
# vfg0     1678.592475
# vfg1       13.576505
# vfg2        3.049993
# dvfg0    3158.581134
# dvfg1       6.359974
# dvfg2       2.402251
# sfg0        0.002945
# sfg1        0.041734
# Length: 64, dtype: float64
# 6th itetation
# update dargs_logpdf:
# before:
# vfg0     1678.592475
# vfg1       13.576505
# vfg2        3.049993
# dvfg0    3158.581134
# dvfg1       6.359974
# dvfg2       2.402251
# sfg0        0.002945
# sfg1        0.041734
# dtype: float64
# after:
# vfg0     27303.839184
# vfg1        13.617407
# vfg2         3.099903
# dvfg0    81538.346804
# dvfg1        6.367666
# dvfg2        2.474746
# sfg0         0.002756
# sfg1         0.042549
# dtype: float64
# MCgeneration start.
# options: {}
# 20.652% completed... acceptance rate: 18.01%
# 41.427% completed... acceptance rate: 18.41%
# 61.931% completed... acceptance rate: 18.66%
# 82.467% completed... acceptance rate: 18.68%
# MCgeneration end.
# MCresults are stored.
# MCinfo are logged.
# vfg
# 9th itetation
# update dargs_logpdf:
# before:
# vfg0     3.105670e+07
# vfg1     1.509841e+01
# vfg2     3.119837e+00
# dvfg0    4.298532e+07
# dvfg1    9.230928e+00
# dvfg2    2.417920e+00
# sfg0     2.611953e-03
# sfg1     4.544889e-02
# dtype: float64
# after:
# vfg0     6.995496e+07
# vfg1     1.491600e+01
# vfg2     3.105328e+00
# dvfg0    7.159813e+07
# dvfg1    9.682943e+00
# dvfg2    2.440443e+00
# sfg0     2.745867e-03
# sfg1     4.465647e-02
# dtype: float64

# %%
display(gen_cont.to_DataFrame()[:].describe())
gen_cont.to_DataFrame()[:].plot(subplots=True,figsize=(16,12))
gen_cont.to_DataFrame()[:].hist(bins=64,figsize=(12,24))
# Out:
#                 vfg0           vfg1           vfg2          dvfg0  \
# count  110001.000000  110001.000000  110001.000000  110001.000000
# mean     -229.473625    -121.120938     -35.081015     242.877461
# std        86.454695      50.282300      10.201862     249.695326
# min      -699.672626    -227.528058     -58.917818      80.441576
# 25%      -247.917110    -176.221505     -45.523211     103.644798
# 50%      -192.819533     -92.415760     -32.768239     110.389635
# 75%      -180.706824     -76.918155     -25.027340     283.147122
# max      -146.178116     -43.480636     -24.901035    1863.004560
#
#                dvfg1          dvfg2           sfg0           sfg1  \
# count  110001.000000  110001.000000  110001.000000  110001.000000
# mean       61.150047      32.811877       0.222684       0.355234
# std        24.374920       3.771199       0.179461       0.078903
# min        18.567506      26.094457       0.000019       0.046811
# 25%        40.002438      30.011885       0.009408       0.307497
# 50%        46.390933      30.044599       0.324949       0.364358
# 75%        88.347013      36.441131       0.377920       0.413810
# max       110.492000      46.401093       0.532089       0.583880
#
#               logpdf
# count  110001.000000
# mean    -4239.578306
# std         3.941200
# min     -4253.886719
# 25%     -4242.545576
# 50%     -4240.724635
# 75%     -4235.623837
# max     -4231.464773
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb4a8080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb44e0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb472b70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb423630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb3d30f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb3d3128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb3a8630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb3550f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcedb37cb70>]],
#       dtype=object)

# %%
gen_cont.to_DataFrame()[300000:600000].plot(subplots=True,figsize=(12,16),layout=(5,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f198f84d828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f199946c208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1991d7bb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198ffad518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1991388e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1991388eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f199193d1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f199a1beb38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f198e8044e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1997ad9e48>]],
#       dtype=object)

# %%
argmax_full = gen_cont.to_DataFrame().sort_values(by="logpdf").iloc[-1]
argmax_last = gen_cont.to_DataFrame()[-100000:].sort_values(by="logpdf").iloc[-1]
display(argmax_full)
display(argmax_last)
argmax_2gaussian = argmax_last.copy()
argmax_2gaussian.sfg0 = 0
logpdf_2gaussian = loglikeli_cont(**argmax_2gaussian[:-1])
display(logpdf_2gaussian)
display(logpdf_2gaussian-argmax_2gaussian.logpdf)
# Out:
# vfg0      -315.324466
# vfg1      -181.495866
# vfg2       -46.258455
# dvfg0      539.338345
# dvfg1       88.116720
# dvfg2       38.665301
# sfg0         0.002410
# sfg1         0.335297
# logpdf   -2458.540754
# Name: 382014, dtype: float64
# vfg0     -2.109136e+06
# vfg1     -1.821582e+02
# vfg2     -4.670919e+01
# dvfg0     3.646009e+06
# dvfg1     8.401631e+01
# dvfg2     3.878459e+01
# sfg0      4.564480e-03
# sfg1      3.206547e-01
# logpdf   -2.467503e+03
# Name: 982155, dtype: float64
# -2481.0262941472038
# -13.523649238140933

# %%
argmax_ = argmax_full[argmax_full.index[:-1]]
display(argmax_)
loglikeli_cont.fit_plot(**argmax_,figsize=(8,4))
plt.xlabel(r"$v_{los}$[km/s]")
plt.xlim((-400,50))
# Out:
# vfg0    -315.324466
# vfg1    -181.495866
# vfg2     -46.258455
# dvfg0    539.338345
# dvfg1     88.116720
# dvfg2     38.665301
# sfg0       0.002410
# sfg1       0.335297
# Name: 382014, dtype: float64
# (-400, 50)

# %%
argmax_ = argmax_last[argmax_last.index[:-1]]
display(argmax_)
loglikeli_cont.fit_plot(**argmax_,figsize=(8,4))
plt.xlabel(r"$v_{los}$[km/s]")
plt.xlim((-400,50))
# Out:
# vfg0    -6.907239e+05
# vfg1    -1.840974e+02
# vfg2    -4.949531e+01
# dvfg0    2.246518e+06
# dvfg1    8.959726e+01
# dvfg2    3.967549e+01
# sfg0     8.780452e-04
# sfg1     3.773287e-01
# Name: 1034323, dtype: float64
# (-400, 50)

# %%
mypairplot(gen_cont.to_DataFrame()[::1000])
# Out:
# Note: The following warnings occur, but no problem.
# UserWarning: The following kwargs were not used by contour: 'label', 'color'
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
mypairplot(gen_cont.to_DataFrame()[-100000:][["sfg0","sfg1","logpdf"]][::10])
# Out:
# Note: The following warnings occur, but no problem.
# UserWarning: The following kwargs were not used by contour: 'label', 'color'
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
beta = 1/np.log(len(loglikeli_cont.vs))
display(1/beta)
bic_ = -gen_cont.to_DataFrame()["logpdf"].max() + (len(gen_cont.to_DataFrame().columns)-1)/2/beta
bic_
# Out:
# 5.123963979403259
# 940.4712482227638

# %%
beta = 1/np.log(len(loglikeli_cont.vs))
bic_ = -logpdf_2gaussian + (3*2-1)/2/beta
bic_
# Out:
# 940.3538598478767

# %%
SPECIFY_NAME = "spectroscopy_cont_refR-re-w-center_plummer_Rcont-1190pc"
FNAME_BASE = "MCMCresult/MCMC{}_{}_{}.csv"
VERSION="v001"
gen_cont.to_csv(FNAME_BASE.format("",SPECIFY_NAME,VERSION))
gen_cont.to_csv(FNAME_BASE.format("log",SPECIFY_NAME,VERSION),output_log=True)

# %% [markdown]
# ## Sig

# %%
# %%time
#display(loglikeli.Rs(0,0).describe())
lnl = loglikeli(**{
        "re":200, "odds":6.5,"dra0":0.0,"dde0":0.0,
        "log10_rs_pc":4, 'log10_rhos_Msunpc3':-2., 'a':2.5, 'b':7., 'g':0.5, 'mlog10_1manib':0., 
        'vmem':-200, 'vfg0':-250, 'vfg1':-200, 'vfg2':-50, 'dvfg0':50, 'dvfg1':50,'dvfg2':50,
        'sfg0':0.3,'sfg1':0.3
    })
display(lnl)
# Out:
# -9936.712805465118
# CPU times: user 24 ms, sys: 4 ms, total: 28 ms
# Wall time: 26.9 ms

# %%
gen = MCgenerator.MCgenerator(
    args_logpdf_init={
 're': 199.28948352120963,
 'odds': 6.110482888180316,
 'dra0': 0.0027107145314206734,
 'dde0': 0.0019431916651246623,
 'log10_rs_pc': 4.61975696265689,
 'log10_rhos_Msunpc3': -2.768076282085142,
 'a': 1.824565306381402,
 'b': 8.478360213945722,
 'g': 0.8232316601071609,
 'mlog10_1manib': 0.10177658300317267,
 'vmem': -292.49186903873334,
 'vfg0': -2263834.1414957047,
 'vfg1': -182.05556974993627,
 'vfg2': -47.587911525642625,
 'dvfg0': 39014865.57475361,
 'dvfg1': 88.55010138144186,
 'dvfg2': 37.47682110572142,
 'sfg0': 0.0030915722406646825,
 'sfg1': 0.4832156433922633
    },
    dargs_logpdf={
        "re":0.1,"odds":0.1,"dra0":0.001,"dde0":0.001,
        "log10_rs_pc":0.05,'log10_rhos_Msunpc3':0.05, 'a':0.05, 'b':0.05, 'g':0.05, 'mlog10_1manib':0.05, 
        'vmem':0.1, 'vfg0':1e7, 'vfg1':1.0, 'vfg2':1, 'dvfg0':1e7, 'dvfg1':2,'dvfg2':1,
        'sfg0':1e-4,'sfg1':0.02
    },
    logpdf_func=loglikeli,
    print_func=display
)
# Out:
# initialization of MCgenerator start.
# function loaded.
# logpdf_initialization completed.
# Data chains are initialized.
# update dargs_logpdf:
# before:
# {}
# after:
# re                    1.000000e-01
# odds                  1.000000e-01
# dra0                  1.000000e-03
# dde0                  1.000000e-03
# log10_rs_pc           5.000000e-02
# log10_rhos_Msunpc3    5.000000e-02
# a                     5.000000e-02
# b                     5.000000e-02
# g                     5.000000e-02
# mlog10_1manib         5.000000e-02
# vmem                  1.000000e-01
# vfg0                  1.000000e+07
# vfg1                  1.000000e+00
# vfg2                  1.000000e+00
# dvfg0                 1.000000e+07
# dvfg1                 2.000000e+00
# dvfg2                 1.000000e+00
# sfg0                  1.000000e-04
# sfg1                  2.000000e-02
# dtype: float64
# MCparameters are initialized.

# %%
Nstep_init = 2000
gen.generate(Nstep_init)
# Out:
# MCgeneration start.
# options: {}
# Process ForkPoolWorker-622:
# Process ForkPoolWorker-620:
# Process ForkPoolWorker-618:
# Process ForkPoolWorker-617:
# Process ForkPoolWorker-623:
# Traceback (most recent call last):
# Process ForkPoolWorker-621:
# Process ForkPoolWorker-619:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Process ForkPoolWorker-624:
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in sigmalos2_vector_using_mykernel
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-59ce092546d5> in <module>()
#       1 Nstep_init = 2000
# ----> 2 gen.generate(Nstep_init)
#
# ~/workspace/git_code/modKI17/Draco/MCgenerator.py in generate(self, num_iter, with_message, proposal_dist)
#     126         if with_message:
#     127             print(mes)
# --> 128         results = [res for res in gen]
#     129         #for i in range(num_iter-1):
#     130         #    results[0] = metropolis(
#
# ~/workspace/git_code/modKI17/Draco/MCgenerator.py in <listcomp>(.0)
#     126         if with_message:
#     127             print(mes)
# --> 128         results = [res for res in gen]
#     129         #for i in range(num_iter-1):
#     130         #    results[0] = metropolis(
#
# ~/workspace/git_code/modKI17/Draco/MCgenerator.py in metropolis_generator(num_iter, logpdf_func, args_logpdf, logpdf_value, dargs_logpdf, push_time, proposal_dist, print_func)
#      27             index = _args_logpdf.index
#      28             )
# ---> 29         logpdf_value_candidate = logpdf_func(**args_logpdf_candidate)
#      30
#      31         acceptance_rate = np.exp(logpdf_value_candidate-_logpdf_value)
#
# <ipython-input-7-398465f74791> in __call__(self, **args)
#      41
#      42     def __call__(self,**args):
# ---> 43         return np.sum(self.loglikelis(**args)) + self.logprior(**args)
#      44
#      45     def is_parameters_in_domain(self,re,odds,dra0,dde0,
#
# <ipython-input-7-398465f74791> in loglikelis(self, re, odds, dra0, dde0, log10_rs_pc, log10_rhos_Msunpc3, a, b, g, mlog10_1manib, vmem, vfg0, vfg1, vfg2, dvfg0, dvfg1, dvfg2, sfg0, sfg1)
#      77             s = 1/(1+ 1/(odds * mem.density_2d_normalized_re(Rs)))
#      78             #sigmalos2 = self.dsph.sigmalos2_interp1d(Rs,step_inner=8,step_outer=16)
# ---> 79             sigmalos = self.dsph.sigmalos_interp1d(Rs,step_around_Rtrunc=4,step_center=2,step_outer=16)
#      80             sfg2 = 1-sfg0-sfg1
#      81
#
# ~/workspace/git_code/modKI17/Draco/dSph_model.py in sigmalos_interp1d(self, R_pc, dR, dRtrunc, step_around_Rtrunc, step_outer, step_center, kind)
#     409         R_pc_ = np.sort(np.unique(np.concatenate((R_pc_zero,R_pc_around_Rtrunc,R_pc_hi_),axis=None)))
#     410         #R_pc_ = np.linspace(Rmin,Rmax,int(n/step))
# --> 411         sigmalos2_ = self.sigmalos2_multi_using_mykernel(R_pc_)
#     412         interpd_func = interp1d(R_pc_, sqrt(sigmalos2_),kind=kind)
#     413         return interpd_func(R_pc) # here R_pc is original, so return unsorted results
#
# ~/workspace/git_code/modKI17/Draco/dSph_model.py in sigmalos2_multi_using_mykernel(self, R_pc)
#     381         R_pc_splited = np.array_split(R_pc,self.ncpu)
#     382         #args = [(Rs,anib,rhos_Msunpc3,rs_pc,a,b,g,re_pc) for Rs in R_pc_v_splited]
# --> 383         ret = p.map(self.sigmalos2_vector_using_mykernel,R_pc_splited)
#     384         p.close()
#     385         return np.concatenate(ret)
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in <listcomp>
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in sigmalos2_vector_using_mykernel
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in sigmalos2_vector_using_mykernel
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 319, in sigmalos2_scaler_using_mykernel
#     integ, abserr =  integrate.quad(self.integrand_sigmalos2_using_mykernel, 1,u_max, args=(R_pc,),points=(1.001,max(u_re,1.08),2.71,u_trunc))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in sigmalos2_vector_using_mykernel
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in <listcomp>
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in <listcomp>
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in sigmalos2_vector_using_mykernel
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in <listcomp>
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 319, in sigmalos2_scaler_using_mykernel
#     integ, abserr =  integrate.quad(self.integrand_sigmalos2_using_mykernel, 1,u_max, args=(R_pc,),points=(1.001,max(u_re,1.08),2.71,u_trunc))
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 319, in sigmalos2_scaler_using_mykernel
#     integ, abserr =  integrate.quad(self.integrand_sigmalos2_using_mykernel, 1,u_max, args=(R_pc,),points=(1.001,max(u_re,1.08),2.71,u_trunc))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 377, in <listcomp>
#     return [sigmalos2_scaler(R_pc) for R_pc in Rs_pc]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 460, in _quad
#     return _quadpack._qagpe(func,a,b,the_points,args,full_output,epsabs,epsrel,limit)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 319, in sigmalos2_scaler_using_mykernel
#     integ, abserr =  integrate.quad(self.integrand_sigmalos2_using_mykernel, 1,u_max, args=(R_pc,),points=(1.001,max(u_re,1.08),2.71,u_trunc))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 319, in sigmalos2_scaler_using_mykernel
#     integ, abserr =  integrate.quad(self.integrand_sigmalos2_using_mykernel, 1,u_max, args=(R_pc,),points=(1.001,max(u_re,1.08),2.71,u_trunc))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 306, in integrand_sigmalos2_using_mykernel
#     return 2 * self.mykernel_over_u(u) *  stellar_model.density_3d(r)/stellar_model.density_2d(arg_R_pc)*GMsun_m3s2 * DM_model.enclosure_mass(r) / parsec * 1e-6
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 460, in _quad
#     return _quadpack._qagpe(func,a,b,the_points,args,full_output,epsabs,epsrel,limit)
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 217, in enclosure_mass
#     rs_pc, rhos_Msunpc3,a,b,g = self.params.rs_pc, self.params.rhos_Msunpc3, self.params.a, self.params.b,self.params.g
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 460, in _quad
#     return _quadpack._qagpe(func,a,b,the_points,args,full_output,epsabs,epsrel,limit)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 460, in _quad
#     return _quadpack._qagpe(func,a,b,the_points,args,full_output,epsabs,epsrel,limit)
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 306, in integrand_sigmalos2_using_mykernel
#     return 2 * self.mykernel_over_u(u) *  stellar_model.density_3d(r)/stellar_model.density_2d(arg_R_pc)*GMsun_m3s2 * DM_model.enclosure_mass(r) / parsec * 1e-6
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/scipy/integrate/quadpack.py", line 460, in _quad
#     return _quadpack._qagpe(func,a,b,the_points,args,full_output,epsabs,epsrel,limit)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/generic.py", line 4370, in __getattr__
#     if self._info_axis._can_hold_identifiers_and_holds_name(name):
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 306, in integrand_sigmalos2_using_mykernel
#     return 2 * self.mykernel_over_u(u) *  stellar_model.density_3d(r)/stellar_model.density_2d(arg_R_pc)*GMsun_m3s2 * DM_model.enclosure_mass(r) / parsec * 1e-6
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 306, in integrand_sigmalos2_using_mykernel
#     return 2 * self.mykernel_over_u(u) *  stellar_model.density_3d(r)/stellar_model.density_2d(arg_R_pc)*GMsun_m3s2 * DM_model.enclosure_mass(r) / parsec * 1e-6
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 217, in enclosure_mass
#     rs_pc, rhos_Msunpc3,a,b,g = self.params.rs_pc, self.params.rhos_Msunpc3, self.params.a, self.params.b,self.params.g
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 255, in mykernel_over_u
#     return 1/u * sqrt(1-1/u2)*((1.5-anib)*u2*hyp2f1(1.0,1.5-anib,1.5,1-u2)-0.5)
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 306, in integrand_sigmalos2_using_mykernel
#     return 2 * self.mykernel_over_u(u) *  stellar_model.density_3d(r)/stellar_model.density_2d(arg_R_pc)*GMsun_m3s2 * DM_model.enclosure_mass(r) / parsec * 1e-6
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/generic.py", line 4371, in __getattr__
#     return self[name]
# KeyboardInterrupt
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 217, in enclosure_mass
#     rs_pc, rhos_Msunpc3,a,b,g = self.params.rs_pc, self.params.rhos_Msunpc3, self.params.a, self.params.b,self.params.g
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 2095, in _can_hold_identifiers_and_holds_name
#     if self.is_object() or self.is_categorical():
#   File "/home/gomesu/workspace/git_code/modKI17/Draco/dSph_model.py", line 99, in density_3d
#     re_pc= self.params.re_pc
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/series.py", line 766, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/generic.py", line 4358, in __getattr__
#     def __getattr__(self, name):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/generic.py", line 4371, in __getattr__
#     return self[name]
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 1576, in is_object
#     return is_object_dtype(self.dtype)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 3100, in get_value
#     k = self._convert_scalar_indexer(k, kind='getitem')
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/series.py", line 766, in __getitem__
#     result = self.index.get_value(self, key)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 1639, in _convert_scalar_indexer
#     if len(self) and not isinstance(self, ABCMultiIndex,):
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/indexes/base.py", line 3103, in get_value
#     tz=getattr(series.dtype, 'tz', None))
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/series.py", line 414, in dtype
#     return self._data.dtype
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/internals.py", line 4718, in dtype
#     @property
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/dtypes/generic.py", line 7, in _check
#     @classmethod
# KeyboardInterrupt
# Process ForkPoolWorker-627:
# Process ForkPoolWorker-626:
# Process ForkPoolWorker-628:
# Process ForkPoolWorker-632:
# Process ForkPoolWorker-625:
# Process ForkPoolWorker-630:
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-631:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Process ForkPoolWorker-629:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt

# %%
df = gen.to_DataFrame()
df.plot(subplots=True,figsize=(8,12),layout=(8,3))
display(gen.to_DataFrame(output_log=True))
display(df.describe())
display(df.logpdf.idxmax())
display(df.iloc[df.logpdf.idxmax()].to_dict())
#display(mypairplot(df[-2000:]))

# %%
# %%time
gen.generate_tuned([20000,20000,200000],proposal_dist="multivariate_normal")
# Out:
# MCgeneration start.
# options: {}
# 0.065% completed... acceptance rate: 23.08%
# 0.125% completed... acceptance rate: 24.00%
# 0.195% completed... acceptance rate: 20.51%
# 0.295% completed... acceptance rate: 18.64%
# 0.395% completed... acceptance rate: 18.99%
# 0.495% completed... acceptance rate: 19.19%
# 0.550% completed... acceptance rate: 19.09%
# 0.615% completed... acceptance rate: 20.33%
# 0.670% completed... acceptance rate: 20.15%
# 0.725% completed... acceptance rate: 19.31%
# 0.780% completed... acceptance rate: 18.59%
# 0.835% completed... acceptance rate: 19.16%
# 0.890% completed... acceptance rate: 18.54%
# 0.945% completed... acceptance rate: 18.52%
# 1.005% completed... acceptance rate: 19.40%
# 1.060% completed... acceptance rate: 19.34%
# 1.130% completed... acceptance rate: 19.03%
# 1.205% completed... acceptance rate: 18.67%
# 1.260% completed... acceptance rate: 19.05%
# 1.315% completed... acceptance rate: 18.25%
# 1.370% completed... acceptance rate: 18.98%
# 1.425% completed... acceptance rate: 18.95%
# 1.480% completed... acceptance rate: 19.26%
# 1.535% completed... acceptance rate: 19.22%
# 1.590% completed... acceptance rate: 19.18%
# 1.645% completed... acceptance rate: 18.84%
# 1.700% completed... acceptance rate: 18.82%
# 1.755% completed... acceptance rate: 18.80%
# 1.810% completed... acceptance rate: 18.23%
# 1.865% completed... acceptance rate: 18.50%
# 1.920% completed... acceptance rate: 18.23%
# 1.975% completed... acceptance rate: 17.97%
# 2.030% completed... acceptance rate: 17.73%
# 2.085% completed... acceptance rate: 17.27%
# 2.140% completed... acceptance rate: 17.52%
# 2.195% completed... acceptance rate: 17.77%
# 2.250% completed... acceptance rate: 17.78%
# 14.215% completed... acceptance rate: 18.50%
# 14.270% completed... acceptance rate: 18.54%
# 14.330% completed... acceptance rate: 18.49%
# 14.385% completed... acceptance rate: 18.49%
# 14.440% completed... acceptance rate: 18.49%
# 14.495% completed... acceptance rate: 18.45%
# 14.550% completed... acceptance rate: 18.38%
# 14.605% completed... acceptance rate: 18.35%
# 14.660% completed... acceptance rate: 18.28%
# 14.715% completed... acceptance rate: 18.28%
# 14.770% completed... acceptance rate: 18.28%
# 14.825% completed... acceptance rate: 18.21%
# 14.880% completed... acceptance rate: 18.31%
# 14.955% completed... acceptance rate: 18.25%
# 15.030% completed... acceptance rate: 18.26%
# 15.105% completed... acceptance rate: 18.24%
# 15.160% completed... acceptance rate: 18.27%
# 15.230% completed... acceptance rate: 18.29%
# 15.295% completed... acceptance rate: 18.31%
# 15.380% completed... acceptance rate: 18.24%
# 15.455% completed... acceptance rate: 18.28%
# 15.515% completed... acceptance rate: 18.34%
# 15.575% completed... acceptance rate: 18.33%
# 15.650% completed... acceptance rate: 18.27%
# 15.710% completed... acceptance rate: 18.27%
# 15.770% completed... acceptance rate: 18.23%
# 15.900% completed... acceptance rate: 18.08%
# 16.015% completed... acceptance rate: 17.98%
# 16.095% completed... acceptance rate: 17.89%
# 16.205% completed... acceptance rate: 17.86%
# 16.315% completed... acceptance rate: 17.74%
# 16.405% completed... acceptance rate: 17.68%
# 16.475% completed... acceptance rate: 17.63%
# 16.580% completed... acceptance rate: 17.52%
# 16.655% completed... acceptance rate: 17.56%
# 16.720% completed... acceptance rate: 17.61%
# 16.785% completed... acceptance rate: 17.58%
# 16.840% completed... acceptance rate: 17.55%
# 16.915% completed... acceptance rate: 17.62%
# 16.970% completed... acceptance rate: 17.62%
# 17.050% completed... acceptance rate: 17.60%
# 17.115% completed... acceptance rate: 17.59%
# 17.170% completed... acceptance rate: 17.53%
# 17.230% completed... acceptance rate: 17.47%
# 17.295% completed... acceptance rate: 17.49%
# 17.365% completed... acceptance rate: 17.48%
# 17.420% completed... acceptance rate: 17.51%
# 17.475% completed... acceptance rate: 17.54%
# 17.530% completed... acceptance rate: 17.71%
# 17.590% completed... acceptance rate: 17.74%
# 17.645% completed... acceptance rate: 17.74%
# 17.705% completed... acceptance rate: 17.71%
# 17.760% completed... acceptance rate: 17.74%
# 17.810% completed... acceptance rate: 17.71%

# %%
df = gen.to_DataFrame()[:]
df_ren = df.rename(
    columns={
        "a":r"$\alpha$","b":r"$\beta$","g":"$\gamma$",
        "re":r"$r_e$","dra0":r"$\delta RA_0$","dra0":r"$\delta RA_0$[deg]","dde0":r"$\delta DE_0$[deg]",
        "log10_rs_pc":r"$\log_{10}r_s$[pc]","log10_rhos_Msunpc3":r"$\log_{10}\rho_s[M_\mathrm{sun}\mathrm{pc}^3]$","mlog10_1manib":r"$-\log_{10}(1-\beta_\mathrm{ani})$"
    })
display(df.describe(percentiles=[0.16,0.5,0.84]))
display(pd.DataFrame(df.iloc[df.logpdf.idxmax()]))
df_ren.plot(subplots=True,layout=(8,3),figsize=(16,12))
df_ren.hist(layout=(6,5),figsize=(12,16),bins=32)
#mypairplot(df[::100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-81c3c720962f> in <module>()
# ----> 1 df = gen.to_DataFrame()[:]
#       2 df_ren = df.rename(
#       3     columns={
#       4         "a":r"$\alpha$","b":r"$\beta$","g":"$\gamma$",
#       5         "re":r"$r_e$","dra0":r"$\delta RA_0$","dra0":r"$\delta RA_0$[deg]","dde0":r"$\delta DE_0$[deg]",
#
# NameError: name 'gen' is not defined

# %%
df[:].plot(subplots=True,layout=(8,3),figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f197b5d7f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1995d0d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f19ae52f5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f199d2d8ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f199af26198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f199af261d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f199a556cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f197b1202e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f197b037898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f197b067e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f197b007438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f197b0289e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f198cdbef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cd64588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cd86b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f198cd38128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198ccdf6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cd08c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f198ccb8278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cc60828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cc87dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f198cc38518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cbdfc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f198cc11358>]],
#       dtype=object)

# %%
df[::10].hist(bins=64,layout=(8,4),figsize=(12,16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-2711889f28b7> in <module>()
# ----> 1 df[::10].hist(bins=64,layout=(8,4),figsize=(12,16))
#
# NameError: name 'df' is not defined

# %%
df.plot.scatter("log10_rs_pc","log10_rhos_Msunpc3",s=1,alpha=0.01)
#df.plot.scatter("log10_rs_pc","logpdf",s=1,alpha=0.01,ylim=[-7640,-7635])
#df.plot.scatter("b","logpdf",s=1,alpha=0.01,ylim=[-7640,-7635])
pd.plotting.scatter_matrix(df[["g","log10_rs_pc","log10_rhos_Msunpc3","logpdf"]],s=1,alpha=0.01)
df.corr()[np.abs(df.corr())>0.1]
# Out:
#                           re      odds      dra0  dde0  log10_rs_pc  \
# re                  1.000000 -0.638452       NaN   NaN          NaN
# odds               -0.638452  1.000000       NaN   NaN          NaN
# dra0                     NaN       NaN  1.000000   NaN          NaN
# dde0                     NaN       NaN       NaN   1.0          NaN
# log10_rs_pc              NaN       NaN       NaN   NaN     1.000000
# log10_rhos_Msunpc3       NaN       NaN       NaN   NaN    -0.725094
# a                        NaN       NaN       NaN   NaN    -0.187621
# b                        NaN       NaN       NaN   NaN     0.103906
# g                        NaN       NaN       NaN   NaN     0.212105
# mlog10_1manib            NaN       NaN -0.166201   NaN          NaN
# vmem                     NaN       NaN       NaN   NaN          NaN
# vfg0                     NaN       NaN       NaN   NaN          NaN
# vfg1                     NaN       NaN       NaN   NaN          NaN
# vfg2                     NaN       NaN       NaN   NaN          NaN
# dvfg0                    NaN       NaN       NaN   NaN          NaN
# dvfg1                    NaN       NaN       NaN   NaN          NaN
# dvfg2                    NaN       NaN       NaN   NaN          NaN
# sfg0                     NaN       NaN       NaN   NaN          NaN
# sfg1                     NaN       NaN       NaN   NaN          NaN
# logpdf                   NaN       NaN       NaN   NaN          NaN
#
#                     log10_rhos_Msunpc3         a         b         g  \
# re                                 NaN       NaN       NaN       NaN
# odds                               NaN       NaN       NaN       NaN
# dra0                               NaN       NaN       NaN       NaN
# dde0                               NaN       NaN       NaN       NaN
# log10_rs_pc                  -0.725094 -0.187621  0.103906  0.212105
# log10_rhos_Msunpc3            1.000000       NaN       NaN -0.776633
# sfg0                     NaN -0.188078       NaN  1.000000 -0.105071 -0.219190
# sfg1                     NaN  0.461705 -0.661570 -0.105071  1.000000       NaN
# logpdf             -0.233180       NaN       NaN -0.219190       NaN  1.000000

# %%
gen.options["push_time"] = 30
gen.generate(200000)

# %% [markdown]
# ## results

# %%
result_df = gen.to_DataFrame()
#resultlog_df = gen.to_DataFrame(output_log=True)
#resultlog_df

# %% [markdown]
# if you already done the calculation, load the result below.

# %%
#result_df = pd.read_csv("MCMCresult/MCMC_refR-re-w-center_v001.csv")
#resultlog_df = pd.read_csv("MCMCresult/MCMClog_refR-re-w-center_v001.csv")

# %%
ploted_stepset = 1
last_MCMC_steps = np.sum(resultlog_df.iter_num.values[-ploted_stepset:])
print("print last {} steps".format(last_MCMC_steps))
#result_df["re[deg]"] = np.rad2deg(result_df.re/draco_prop.DIST)
result_df[-last_MCMC_steps:].hist(bins=64,figsize=(12,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-e31a9037d908> in <module>()
#       1 ploted_stepset = 1
# ----> 2 last_MCMC_steps = np.sum(resultlog_df.iter_num.values[-ploted_stepset:])
#       3 print("print last {} steps".format(last_MCMC_steps))
#       4 #result_df["re[deg]"] = np.rad2deg(result_df.re/draco_prop.DIST)
#       5 result_df[-last_MCMC_steps:].hist(bins=64,figsize=(12,6))
#
# ~/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iter_num'

# %%
mypairplot(result_df[-last_MCMC_steps::50])
#mypairplot(result_df[-lastMCMCsteps])

# %%
last_MCMC_steps = 200000
stats = result_df[-last_MCMC_steps:].describe(percentiles=(0.16,0.5,0.84))
stats
# Out:
#                   re           odds           dra0           dde0  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean      188.137883       7.598996      -0.000229      -0.001409
# std         5.372065       1.012546       0.006732       0.003277
# min       167.629480       4.162622      -0.025555      -0.013559
# 16%       182.968513       6.603586      -0.007099      -0.004706
# 50%       187.970099       7.561568      -0.000245      -0.001366
# 84%       193.576964       8.526456       0.006642       0.001947
# max       207.223211      11.998508       0.027519       0.010623
#
#          log10_rs_pc  log10_rhos_Msunpc3              a              b  \
# count  200000.000000       200000.000000  200000.000000  200000.000000
# mean        3.994178           -2.042836       1.830047       6.381247
# std         0.614413            0.775017       0.682310       1.983562
# min         2.407135           -3.966075       0.516943       3.001170
# 16%         3.288672           -2.924294       1.039881       4.048005
# 50%         4.028340           -2.022903       1.841995       6.283647
# 84%         4.677730           -1.196789       2.631638       8.672738
# max         4.999939           -0.034607       2.999188       9.999800
#
#                    g  mlog10_1manib           vmem          vfg0  \
# count  200000.000000  200000.000000  200000.000000  2.000000e+05
# mean        0.707114       0.142450    -292.857904 -8.889518e+07
# std         0.300879       0.144171       0.420385  8.244957e+07
# min         0.001458      -0.402851    -294.393366 -2.995867e+08
# 16%         0.366527       0.003957    -293.269382 -1.846669e+08
# 50%         0.728248       0.129716    -292.872960 -6.284425e+07
# 84%         1.029828       0.281176    -292.408063 -9.999661e+06
# max         1.199620       0.711882    -291.444300 -1.930374e+04
#
#                 vfg1           vfg2         dvfg0          dvfg1  \
# count  200000.000000  200000.000000  2.000000e+05  200000.000000
# mean     -177.470099     -47.226358  1.281190e+08      94.496254
# std         9.375997       2.897717  8.643491e+07       4.618821
# min      -210.243135     -58.595984  1.924445e+04      77.523724
# 16%      -186.725327     -50.058005  2.859714e+07      89.932980
# 50%      -177.040420     -47.255614  1.207288e+08      94.207579
# 84%      -168.414533     -44.478224  2.317714e+08      98.995718
# max      -142.224100     -37.087936  2.999119e+08     112.305598
#
#                dvfg2           sfg0           sfg1         logpdf
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       36.921645       0.002180       0.489103   -7642.684828
# std         2.377803       0.001799       0.037951       3.105313
# min        28.905824       0.000002       0.360221   -7659.782185
# 16%        34.633822       0.000609       0.452406   -7645.678627
# 50%        36.852454       0.001653       0.488723   -7642.484739
# 84%        39.293552       0.003877       0.525753   -7639.822086
# max        46.059066       0.011276       0.654239   -7635.227608

# %%
plots_likelis = pd.DataFrame()
#plots_likelis["R"] = Rs # ideally loglikeli.R but approzimately here we use Rs
plots_likelis["R"] = loglikeli.Rs(dra0=stats.dra0.loc["50%"],dde0=stats.dde0.loc["50%"])
plots_likelis["prob"] = np.exp(np.log(2*np.pi*plots_likelis.R)+loglikeli.loglikelis(**(stats[["re","odds","dra0","dde0"]].loc["50%"])))
plots_likelis = plots_likelis.sort_values(by="R")

fig,ax = plt.subplots()
plots_likelis[::].plot(x="R",y="prob",ax=ax,figsize=(12,6))
display(plots_likelis[::].hist("R",bins=32,density=True,alpha=0.3,ax=ax))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-b13e08e513b3> in <module>()
#       2 #plots_likelis["R"] = Rs # ideally loglikeli.R but approzimately here we use Rs
#       3 plots_likelis["R"] = loglikeli.Rs(dra0=stats.dra0.loc["50%"],dde0=stats.dde0.loc["50%"])
# ----> 4 plots_likelis["prob"] = np.exp(np.log(2*np.pi*plots_likelis.R)+loglikeli.loglikelis(**(stats[["re","odds","dra0","dde0"]].loc["50%"])))
#       5 plots_likelis = plots_likelis.sort_values(by="R")
#       6
#
# TypeError: loglikelis() missing 15 required positional arguments: 'log10_rs_pc', 'log10_rhos_Msunpc3', 'a', 'b', 'g', 'mlog10_1manib', 'vmem', 'vfg0', 'vfg1', 'vfg2', 'dvfg0', 'dvfg1', 'dvfg2', 'sfg0', and 'sfg1'

# %%
plots_loglikelis = pd.DataFrame()
plots_loglikelis["R"] = loglikeli.Rs(dra0=stats.dra0.loc["50%"],dde0=stats.dde0.loc["50%"]) # ideally loglikeli.R but approzimately here we use Rs
plots_loglikelis["loglikeli"] = loglikeli.loglikelis(**(stats[["re","n","odds","dra0","dde0"]].loc["50%"]))
plots_loglikelis = plots_loglikelis.sort_values(by="R")

fig,ax = plt.subplots()
plots_loglikelis[::].plot(x="R",y="loglikeli",ax=ax,figsize=(12,6))

# %% [markdown]
# ## export

# %%
SPECIFY_NAME = "spectroscopy_sig_refR-re-w-center_plummer_Rsig-3000pc"
FNAME_BASE = "MCMCresult/MCMC{}_{}_{}.csv"
VERSION="v002"
result_df = df
result_df.to_csv(FNAME_BASE.format("",SPECIFY_NAME,VERSION),index=None)
resultlog_df.to_csv(FNAME_BASE.format("log",SPECIFY_NAME,VERSION),index=None)

# %% [markdown]
# # WBIC calculation

# %%
#update likelihood
class KI17_loglikelihood_mod:
    def __init__(self,dRAs,dDEs,beta=1):
        self.dRAs = dRAs
        self.dDEs = dDEs
        self.RoI_R = np.max(self.Rs(0,0)) # use Rs.max as the RoI
        self.beta = beta
        print(Rs.describe())
        print("beta: {}".format(self.beta)) if beta != 1 else None
        self.mem = dSph_model.plummer_model(re_pc=100)
        self.fg = dSph_model.uniform2d_model(Rmax_pc=self.RoI_R)

    def Rs(self,dra0,dde0):
        return coord.projected_distance(
            dist=DIST,
            ra_center = RA0+dra0,
            de_center = DE0+dde0,
            ra = RA0+self.dRAs,
            de = DE0+self.dDEs,
            dtype="deg")
        
    def __call__(self,re,odds,dra0,dde0):
        if re<0 or odds<0:
            return -np.inf
        else:
            return np.sum(self.loglikelis(re,odds,dra0,dde0))
    def loglikelis(self,re,odds,dra0,dde0):
        if re<0 or odds<0:
            return -np.inf
        else:
            mem,fg = self.mem,self.fg
            mem.update({"re_pc":re})
            ref_R = re
            
            C1 = 1/mem.cdf_R(self.RoI_R)
            C0 = fg.density_2d(self.RoI_R) # fg.density_2d returns constant for arbitrary input
            #s = C0/(sigmafg*mem.density_2d(self.Rs)*C1 + C0)
            #s = C0/(sigmafg*mem.density_2d(self.Rs)*C1)
            s = 1/(1+ 1/odds * mem.density_2d(ref_R)/mem.mean_density_2d(self.RoI_R))
            
            arg_proj_dist_deg = {
                "ra":self.dRAs+RA0,"de":self.dDEs+DE0,
                "ra_center":RA0+dra0,"de_center":DE0+dde0
            }
            Rs = coord.projected_distance(dist=DIST,**arg_proj_dist_deg,dtype="deg")
            ret = np.log(s*C1*mem.density_2d(Rs)+(1-s)*C0)

            return self.beta * ret

# %%
loglikeli_wbic = KI17_loglikelihood_mod(dRAs=df_deg.x,dDEs=df_deg.y,beta=1/np.log(len(df_deg)))

# %%
gen_wbic = MCgenerator.MCgenerator(
    args_logpdf_init={"re":180,"n":0.8,"odds":6.5,"dra0":0.0,"dde0":0.0},
    dargs_logpdf={"re":5.0,"n":0.1,"odds":0.5,"dra0":0.01,"dde0":0.01},
    logpdf_func=loglikeli_wbic
)

# %%
gen_wbic.generate(5000)

# %%
gen_wbic.to_DataFrame().plot(subplots=True)

# %%
gen_wbic.generate_tuned((5000,5000,5000))

# %%
gen_wbic.to_DataFrame().plot(subplots=True)

# %%
gen_wbic.generate(100000)

# %%
df_wbic = gen_wbic.to_DataFrame()[-100000:]
df_wbiclog = gen_wbic.to_DataFrame(output_log=True)
mypairplot(df_wbic[::20])

# %%
wbic = -df_wbic.logpdf.mean()/loglikeli_wbic.beta
bic = -gen.to_DataFrame()[-100000:].logpdf.max() + len(gen.args_logpdf_init)/loglikeli_wbic.beta /2
print(" BIC:{}\nWBIC:{}".format(bic,wbic))

# %%
fname = FNAME_BASE
specify_name = SPECIFY_NAME+"_wbic"
version = VERSION
df_wbic.to_csv(fname.format("",specify_name,version),index=None)
resultlog_df.to_csv(fname.format("log",specify_name,version),index=None)
