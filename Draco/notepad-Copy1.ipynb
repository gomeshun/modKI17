# %% [markdown]
# # initialization

# %%
from plot_setup import * 
import MCgenerator, dSph_model, coord
from sympy import *
init_printing()

# %%
dSph_property = pd.read_csv("dSph_property.csv",index_col=0)
draco_prop = dSph_property.loc["Draco"]
RA0 = draco_prop.RAdeg
DE0 = draco_prop.DEdeg
DIST = draco_prop.DIST

# %% [markdown]
# # load MCMC result

# %%
modKI17_result = pd.read_csv("MCMCresult/MCMC_refR-re-w-center_v002.csv"),pd.read_csv("MCMCresult/MCMClog_refR-re-w-center_v002.csv")
modKI17_exp2d_result = pd.read_csv("MCMCresult/MCMC_refR-re-w-center_exp2d_v001.csv"),pd.read_csv("MCMCresult/MCMClog_refR-re-w-center_exp2d_v001.csv")
modKI17_sersic_result = pd.read_csv("MCMCresult/MCMC_refR-re-w-center_sersic_v001.csv"),pd.read_csv("MCMCresult/MCMClog_refR-re-w-center_sersic_v001.csv")

# %%
display(modKI17_result[1])
# Out:
#        dde0      dra0      odds        re  iter_num
# 0  0.010000  0.010000  0.500000  5.000000      5000
# 1  0.010000  0.010000  0.500000  5.000000      5000
# 2  0.003449  0.007200  0.538013  6.101275      5000
# 3  0.003094  0.006654  0.509708  5.673372      5000
# 4  0.003159  0.007153  0.476415  5.199561    200000
# 5  0.003159  0.007153  0.476415  5.199561    200000
# 6  0.003159  0.007153  0.476415  5.199561    200000

# %% [markdown]
#  # results

# %% [markdown]
# ## Plummer model

# %%
df,dflog = modKI17_result

# %%
display(mypairplot(modKI17_result[0][-200000::25]))
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
df[-200000::25].describe(percentiles=(.16,.5,.84))
# Out:
#                 re         odds         dra0         dde0        logpdf
# count  8000.000000  8000.000000  8000.000000  8000.000000   8000.000000
# mean    191.050424     8.788722     0.004192    -0.001929 -54956.495964
# std       5.762468     0.514483     0.006969     0.003306      1.389274
# min     171.791686     7.173772    -0.021798    -0.013367 -54967.275341
# 16%     185.306685     8.268653    -0.002769    -0.005247 -54957.731605
# 50%     190.956967     8.770715     0.004209    -0.001962 -54956.196589
# 84%     196.826595     9.303274     0.011083     0.001390 -54955.223478
# max     214.363188    11.155381     0.029019     0.011371 -54954.500846

# %% [markdown]
# ## Exp2d model

# %%
df,dflog = modKI17_exp2d_result

# %%
display(dflog)
# Out:
#        dde0      dra0      odds        re  iter_num
# 0  0.010000  0.010000  0.500000  5.000000      5000
# 1  0.010000  0.010000  0.500000  5.000000      5000
# 2  0.003167  0.006883  0.562658  3.177008      5000
# 3  0.003080  0.006884  0.545004  2.994798      5000
# 4  0.003198  0.007108  0.508639  3.003558    200000

# %%
display(mypairplot(dfS[-200000::25]))
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %%
df[-200000:].describe(percentiles=(.16,.5,.84))
# Out:
#                   re           odds           dra0           dde0  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean      105.245195       9.406747      -0.002561      -0.003395
# std         3.049089       0.526683       0.006750       0.003186
# min        94.138975       7.499265      -0.032832      -0.016672
# 16%       102.224591       8.883208      -0.009306      -0.006545
# 50%       105.195983       9.390294      -0.002521      -0.003384
# 84%       108.275350       9.933851       0.004174      -0.000243
# max       118.024140      11.619648       0.025697       0.011297
#
#               logpdf
# count  200000.000000
# mean   -54956.385412
# std         1.396944
# min    -54967.210668
# 16%    -54957.656007
# 50%    -54956.067082
# 84%    -54955.107145
# max    -54954.413809

# %% [markdown]
# ## Sersic model

# %%
df,dflog = modKI17_sersic_result

# %%
dflog
# Out:
#        dde0      dra0         n      odds        re  iter_num
# 0  0.010000  0.010000  0.100000  0.500000  5.000000      5000
# 1  0.010000  0.010000  0.100000  0.500000  5.000000      5000
# 2  0.003425  0.006785  0.065018  0.628653  4.858124      5000
# 3  0.003236  0.006263  0.064941  0.577026  4.553125      5000
# 4  0.003352  0.007109  0.068508  0.627723  4.804318    200000

# %%
mypairplot(df[-200000::100])
# Out:
# Note: The following warnings occur, but no problem.
# ...
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# /home/gomesu/.pyenv/versions/anaconda3-5.2.0/lib/python3.6/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# ...

# %% [markdown]
# # BIC, WBIC

# %%
KI17wbic,KI17wbiclog = pd.read_csv("MCMCresult/MCMC_refR-re-w-center_wbic_v002.csv"),pd.read_csv("MCMCresult/MCMClog_refR-re-w-center_v002.csv")

# %%
wbic = -KI17wbic.logpdf.mean()/loglikeli_wbic.beta
#bic = -gen.to_DataFrame()[-100000:].logpdf.max() + 4/loglikeli_wbic.beta /2
print(" BIC:{}\nWBIC:{}".format(bic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-d2dd88c0941f> in <module>()
# ----> 1 wbic = -KI17wbic.logpdf.mean()/loglikeli_wbic.beta
#       2 #bic = -gen.to_DataFrame()[-100000:].logpdf.max() + 4/loglikeli_wbic.beta /2
#       3 print(" BIC:{}\nWBIC:{}".format(bic))
#
# NameError: name 'loglikeli_wbic' is not defined

# %% [markdown]
# # Note

# %%
cmd = np.loadtxt("Draco_CMDcut.csv",delimiter=",")
display(cmd[:,0])
plt.plot(cmd[:,0],cmd[:,1])
# Out:
# array([ 0.55315883,  0.84641732,  1.07295951,  2.1573286 ,  1.74087863,
#         0.77390458,  0.684392  , -0.05496306, -0.35504897, -0.37905951,
#         0.13744201,  0.6009508 ])

# %%
R,re = symbols("R r_e",positive=True) 
cdf = integrate(2*pi*R*(1/2/pi/re**2)*exp(-R/re) ,(R,0,R))
cdf
# Out:
#                          -R
#                          ───
#                           rₑ
#       (-1.0⋅R - 1.0⋅rₑ)⋅ℯ
# 1.0 + ──────────────────────
#                 rₑ

# %%
solve(cdf-1/2,R)
# Out:
# [1.67834699001666⋅rₑ]

# %%
r = symbols("r",positive=True)
l = symbols("l")
Hernquist = 1/r/(r+re)**3

# %%
integrate(Hernquist.subs(r,sqrt(R**2+l**2)),(l,-oo,oo))
# Out:
# ∞
# ⌠
# ⎮                  1
# ⎮  ───────────────────────────────── dl
# ⎮                                  3
# ⎮     _________ ⎛        _________⎞
# ⎮    ╱  2    2  ⎜       ╱  2    2 ⎟
# ⎮  ╲╱  R  + l  ⋅⎝rₑ + ╲╱  R  + l  ⎠
# ⌡
# -∞
