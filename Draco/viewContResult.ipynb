# %%
from plot_setup import *

# %%
draco = pd.read_csv("dra_sspp2.csv")
draco
# Out:
#       RAh  RAm    RAs  pmDEd  DEm   DEs   Vlos  e_Vlos  Teff  e_Teff  logg  \
# 0      17   20   2.76     57   48  57.2 -294.1     2.6  5923     752   3.7
# 1      17   19  29.68     57   42  58.6 -205.1     1.1  4935     244   3.1
# 2      17   19  44.45     57   47  27.3 -283.1     1.1  5113     264   3.0
# 3      17   20  19.32     57   51  19.5 -277.5     1.1  4886     259   1.2
# 4      17   20   0.93     57   45  11.2 -297.8     0.7  4646     130   1.7
# 5      17   19  31.87     57   33  34.7 -309.9     0.4  4644      73   1.4
# 6      17   20  21.12     57   49  27.2 -294.9     0.4  4680      59   1.0
# 7      17   20  24.91     57   48  42.8 -310.9     1.0  4759     220   2.5
# 8      17   20  18.60     57   46   1.1 -302.8     0.5  4792      90   1.4
# 9      17   20  23.74     57   24   2.5  -63.0     0.8  5070     116   5.0
# 10     17   20  29.14     57   25   2.9 -187.9     0.5  5694     106   4.2
# ...

# %%
df3000 = pd.read_csv("MCMCresult/MCMC_spectroscopy_cont_refR-re-w-center_plummer_Rcont-3000pc_v001.csv")
df1900 = pd.read_csv("MCMCresult/MCMC_spectroscopy_cont_refR-re-w-center_plummer_Rcont-1900pc_v001.csv")
df830 = pd.read_csv("MCMCresult/MCMC_spectroscopy_cont_refR-re-w-center_plummer_Rcont-830pc_v001.csv")

# %%
df3000.plot(subplots=True,figsize=(12,8),layout=(5,2))
df3000[:100000].describe()
# Out:
#                 vfg0           vfg1           vfg2          dvfg0  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     -143.266726     -44.039354      -4.547285      84.980859
# std        29.513762       4.396499       0.039636      16.504737
# min      -352.502119     -65.761937      -4.638695      39.911583
# 25%      -161.822859     -46.934746      -4.577103      73.801020
# 50%      -141.386956     -43.917130      -4.539009      83.167564
# 75%      -121.613102     -41.094188      -4.513142      94.456975
# max       -51.376811     -27.088708      -4.486883     192.040225
#
#                dvfg1          dvfg2           sfg0           sfg1  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       34.192889       0.543947       0.196774       0.748142
# std         3.653858       0.024900       0.066599       0.069052
# min        22.067508       0.467027       0.012447       0.445006
# ...

# %%
df1900.plot(subplots=True,figsize=(12,8),layout=(5,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcbceab56a0>,
# ...
#       dtype=object)

# %%
df830.plot(subplots=True,figsize=(12,8),layout=(5,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcbceb0feb8>,
# ...
#       dtype=object)

# %%
stats3000 = df3000[-100000:].describe(percentiles=(0.16,0.5,0.84))
stats3000
# Out:
#                vfg0           vfg1           vfg2         dvfg0  \
# count  1.000000e+05  100000.000000  100000.000000  1.000000e+05
# mean  -1.507295e+08    -144.637377     -41.390891  1.478885e+08
# std    8.799331e+07      29.692455       4.159772  8.754563e+07
# min   -2.999881e+08    -265.813025     -58.294398  4.248368e+02
# 16%   -2.545847e+08    -174.902511     -45.374022  4.438846e+07
# 50%   -1.528387e+08    -142.726192     -41.402049  1.461514e+08
# 84%   -4.522815e+07    -114.917571     -37.188949  2.520412e+08
# max   -1.685479e+04     -52.778100     -25.135108  2.999694e+08
#
#                dvfg1          dvfg2           sfg0           sfg1  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       84.256861      34.367834       0.008092       0.196325
# std        16.291192       3.448231       0.008318       0.066603
# min        38.983467      24.549092       0.000001       0.020586
# ...

# %%
stats1900 = df1900[-100000:].describe(percentiles=(0.16,0.5,0.84))
stats1900
# Out:
#                vfg0           vfg1           vfg2         dvfg0  \
# count  1.000000e+05  100000.000000  100000.000000  1.000000e+05
# mean  -1.493725e+08    -182.904346     -44.757806  1.513305e+08
# std    8.741531e+07      25.841151       3.812642  8.611764e+07
# min   -2.997304e+08    -273.867881     -59.634237  1.137320e+05
# 16%   -2.528546e+08    -209.319357     -48.491910  4.947201e+07
# 50%   -1.483452e+08    -181.832189     -44.755849  1.530906e+08
# 84%   -4.545766e+07    -156.738134     -40.968448  2.523340e+08
# max   -9.411133e+04     -91.826174     -30.069813  2.999994e+08
#
#                dvfg1          dvfg2          sfg0           sfg1  \
# count  100000.000000  100000.000000  1.000000e+05  100000.000000
# mean       91.364127      35.709047  5.598828e-03       0.233378
# std        14.164406       3.023794  5.743586e-03       0.054386
# min        48.803026      26.437890  2.991104e-07       0.083957
# ...

# %%
stats830 = df830[-100000:].describe(percentiles=(0.16,0.5,0.84))
stats830
# Out:
#                vfg0           vfg1           vfg2         dvfg0  \
# count  1.000000e+05  100000.000000  100000.000000  1.000000e+05
# mean  -1.021471e+08    -182.387710     -47.775157  1.442733e+08
# std    8.267269e+07      11.765330       2.943065  8.262664e+07
# min   -2.999956e+08    -224.980403     -59.266026  2.310194e+05
# 16%   -2.014526e+08    -194.515323     -50.659814  4.931896e+07
# 50%   -8.115172e+07    -182.099642     -47.795345  1.406854e+08
# 84%   -1.706568e+07    -170.726561     -44.865039  2.423433e+08
# max   -6.286107e+03    -142.252476     -37.092167  2.999924e+08
#
#                dvfg1          dvfg2          sfg0           sfg1  \
# count  100000.000000  100000.000000  1.000000e+05  100000.000000
# mean       93.134480      38.022232  2.560168e-03       0.406444
# std         6.250573       2.366538  1.936155e-03       0.041992
# min        72.572248      29.912632  2.115722e-07       0.269222
# ...

# %%
mls = pd.DataFrame()
mls = mls.append(df3000.iloc[df3000[-100000:].logpdf.idxmax()],ignore_index=True)
mls = mls.append(df1900.iloc[df1900[-100000:].logpdf.idxmax()],ignore_index=True)
mls = mls.append(df830.iloc[df830[-100000:].logpdf.idxmax()],ignore_index=True)
mls
# Out:
#           dvfg0      dvfg1      dvfg2       logpdf      sfg0      sfg1  \
# 0  8.463548e+07  74.962349  33.529201  -678.204604  0.001121  0.175863
# 1  7.755866e+07  83.749499  35.272641  -927.637513  0.000558  0.214641
# 2  1.060011e+07  86.314607  38.960940 -4242.210694  0.002781  0.375436
#
#            vfg0        vfg1       vfg2
# 0 -1.211323e+08 -146.889341 -40.999184
# 1 -1.336386e+08 -188.273823 -45.213205
# 2 -5.028065e+06 -195.199865 -48.218231

# %%
medians = pd.DataFrame()
stds = pd.DataFrame()
medians = medians.append(stats3000.loc["50%"],ignore_index=True)
medians = medians.append(stats1900.loc["50%"],ignore_index=True)
medians = medians.append(stats830.loc["50%"],ignore_index=True)
stds = stds.append(stats3000.loc["std"],ignore_index=True)
stds = stds.append(stats1900.loc["std"],ignore_index=True)
stds = stds.append(stats830.loc["std"],ignore_index=True)

# %%
#medians["1900"] = stats1900.loc["50%"]
#medians["830"] = stats830.loc["50%"]
#stds["3000"] = stats3000.loc["std"]
#stds["1900"] = stats1900.loc["std"]
#stds["830"] = stats830.loc["std"]
display(medians)
display(stds)
# Out:
#           dvfg0      dvfg1      dvfg2       logpdf      sfg0      sfg1  \
# 0  1.461514e+08  82.354877  34.095047  -681.280328  0.005497  0.188423
# 1  1.530906e+08  90.707427  35.553671  -930.598779  0.003766  0.229337
# 2  1.406854e+08  92.598947  38.016454 -4246.767822  0.002123  0.406646
#
#            vfg0        vfg1       vfg2
# 0 -1.528387e+08 -142.726192 -41.402049
# 1 -1.483452e+08 -181.832189 -44.755849
# 2 -8.115172e+07 -182.099642 -47.795345
#           dvfg0      dvfg1     dvfg2    logpdf      sfg0      sfg1  \
# 0  8.754563e+07  16.291192  3.448231  1.988551  0.008318  0.066603
# 1  8.611764e+07  14.164406  3.023794  1.880625  0.005744  0.054386
# 2  8.262664e+07   6.250573  2.366538  2.024598  0.001936  0.041992
#
#            vfg0       vfg1      vfg2
# 0  8.799331e+07  29.692455  4.159772
# 1  8.741531e+07  25.841151  3.812642
# 2  8.267269e+07  11.765330  2.943065

# %%
medians.plot(style=".",subplots=True,layout=(2,5),figsize=(8,12),yerr=stds,xerr=0,xlim=(-2,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb9e0e9128>,
# ...
#       dtype=object)

# %%
mls.plot(style=".",subplots=True,layout=(2,5),figsize=(8,12),yerr=stds,xerr=0,xlim=(-2,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcb9e3e77f0>,
# ...
#       dtype=object)
